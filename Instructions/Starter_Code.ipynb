# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
#!pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.9.1-cp38-cp38-win_amd64.whl (444.1 MB)
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.26.0-cp38-cp38-win_amd64.whl (1.5 MB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from tensorflow) (3.10.0.2)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: setuptools in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from tensorflow) (58.0.4)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.2.0-py3-none-any.whl (123 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from tensorflow) (1.16.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from tensorflow) (2.10.0)
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: packaging in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from tensorflow) (21.0)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from tensorflow) (1.12.1)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp38-cp38-win_amd64.whl (895 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.47.0-cp38-cp38-win_amd64.whl (3.6 MB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.11.0-py2.py3-none-any.whl (167 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\austi\anaconda3\envs\pythondata\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=944e77b3409068f6b40b28f9085e049a0784e629f094257d8785e60401280993
#   Stored in directory: c:\users\austi\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built termcolor
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-1.2.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-1.12 gast-0.4.0 google-auth-2.11.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.47.0 keras-2.9.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN','NAME'], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = application_df['APPLICATION_TYPE'].value_counts().loc[lambda x : x<500].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = application_df['CLASSIFICATION'].value_counts().loc[lambda x : x<100].index.tolist()
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dum_df = pd.get_dummies(application_df)
application_dum_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 45 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_dum_df.drop(['IS_SUCCESSFUL'], axis=1)
y = application_dum_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=4, activation="sigmoid", input_dim=44))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=4, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 4)                 180
#
#  dense_4 (Dense)             (None, 4)                 20
#
#  dense_5 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 205
# Trainable params: 205
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 660us/step - loss: 0.6509 - accuracy: 0.6471
# Epoch 2/100
# 804/804 [==============================] - 1s 656us/step - loss: 0.5834 - accuracy: 0.7231
# Epoch 3/100
# 804/804 [==============================] - 1s 637us/step - loss: 0.5733 - accuracy: 0.7268
# Epoch 4/100
# 804/804 [==============================] - 1s 645us/step - loss: 0.5691 - accuracy: 0.7281
# Epoch 5/100
# 804/804 [==============================] - 1s 642us/step - loss: 0.5660 - accuracy: 0.7292
# Epoch 6/100
# 804/804 [==============================] - 1s 641us/step - loss: 0.5638 - accuracy: 0.7292
# Epoch 7/100
# 804/804 [==============================] - 1s 646us/step - loss: 0.5619 - accuracy: 0.7295
# Epoch 8/100
# 804/804 [==============================] - 1s 646us/step - loss: 0.5604 - accuracy: 0.7293
# Epoch 9/100
# 804/804 [==============================] - 1s 653us/step - loss: 0.5589 - accuracy: 0.7306
# Epoch 10/100
# 804/804 [==============================] - 1s 643us/step - loss: 0.5581 - accuracy: 0.7298
# Epoch 11/100
# 804/804 [==============================] - 1s 642us/step - loss: 0.5572 - accuracy: 0.7306
# Epoch 12/100
# 804/804 [==============================] - 1s 642us/step - loss: 0.5566 - accuracy: 0.7299
# Epoch 13/100
# 804/804 [==============================] - 1s 645us/step - loss: 0.5559 - accuracy: 0.7302
# Epoch 14/100
# 804/804 [==============================] - 1s 651us/step - loss: 0.5555 - accuracy: 0.7301
# Epoch 15/100
# 804/804 [==============================] - 1s 641us/step - loss: 0.5550 - accuracy: 0.7303
# Epoch 16/100
# 804/804 [==============================] - 1s 638us/step - loss: 0.5546 - accuracy: 0.7306
# Epoch 17/100
# 804/804 [==============================] - 1s 639us/step - loss: 0.5543 - accuracy: 0.7299
# Epoch 18/100
# 804/804 [==============================] - 1s 636us/step - loss: 0.5540 - accuracy: 0.7305
# Epoch 19/100
# 804/804 [==============================] - 1s 638us/step - loss: 0.5537 - accuracy: 0.7294
# Epoch 20/100
# 804/804 [==============================] - 1s 636us/step - loss: 0.5535 - accuracy: 0.7297
# Epoch 21/100
# 804/804 [==============================] - 1s 648us/step - loss: 0.5533 - accuracy: 0.7295
# Epoch 22/100
# 804/804 [==============================] - 1s 643us/step - loss: 0.5530 - accuracy: 0.7303
# Epoch 23/100
# 804/804 [==============================] - 1s 640us/step - loss: 0.5529 - accuracy: 0.7300
# Epoch 24/100
# 804/804 [==============================] - 1s 646us/step - loss: 0.5527 - accuracy: 0.7308
# Epoch 25/100
# 804/804 [==============================] - 1s 651us/step - loss: 0.5526 - accuracy: 0.7304
# Epoch 26/100
# 804/804 [==============================] - 1s 648us/step - loss: 0.5523 - accuracy: 0.7294
# Epoch 27/100
# 804/804 [==============================] - 1s 659us/step - loss: 0.5523 - accuracy: 0.7305
# Epoch 28/100
# 804/804 [==============================] - 1s 656us/step - loss: 0.5520 - accuracy: 0.7304
# Epoch 29/100
# 804/804 [==============================] - 1s 666us/step - loss: 0.5520 - accuracy: 0.7296
# Epoch 30/100
# 804/804 [==============================] - 1s 660us/step - loss: 0.5519 - accuracy: 0.7294
# Epoch 31/100
# 804/804 [==============================] - 1s 663us/step - loss: 0.5518 - accuracy: 0.7294
# Epoch 32/100
# 804/804 [==============================] - 1s 662us/step - loss: 0.5516 - accuracy: 0.7297
# Epoch 33/100
# 804/804 [==============================] - 1s 671us/step - loss: 0.5515 - accuracy: 0.7304
# Epoch 34/100
# 804/804 [==============================] - 1s 664us/step - loss: 0.5514 - accuracy: 0.7304
# Epoch 35/100
# 804/804 [==============================] - 1s 683us/step - loss: 0.5512 - accuracy: 0.7300
# Epoch 36/100
# 804/804 [==============================] - 1s 675us/step - loss: 0.5512 - accuracy: 0.7303
# Epoch 37/100
# 804/804 [==============================] - 1s 676us/step - loss: 0.5511 - accuracy: 0.7306
# Epoch 38/100
# 804/804 [==============================] - 1s 675us/step - loss: 0.5509 - accuracy: 0.7309
# Epoch 39/100
# 804/804 [==============================] - 1s 667us/step - loss: 0.5510 - accuracy: 0.7312
# Epoch 40/100
# 804/804 [==============================] - 1s 671us/step - loss: 0.5508 - accuracy: 0.7310
# Epoch 41/100
# 804/804 [==============================] - 1s 666us/step - loss: 0.5507 - accuracy: 0.7305
# Epoch 42/100
# 804/804 [==============================] - 1s 668us/step - loss: 0.5507 - accuracy: 0.7305
# Epoch 43/100
# 804/804 [==============================] - 1s 677us/step - loss: 0.5506 - accuracy: 0.7300
# Epoch 44/100
# 804/804 [==============================] - 1s 669us/step - loss: 0.5505 - accuracy: 0.7298
# Epoch 45/100
# 804/804 [==============================] - 1s 671us/step - loss: 0.5504 - accuracy: 0.7305
# Epoch 46/100
# 804/804 [==============================] - 1s 676us/step - loss: 0.5503 - accuracy: 0.7298
# Epoch 47/100
# 804/804 [==============================] - 1s 671us/step - loss: 0.5502 - accuracy: 0.7304
# Epoch 48/100
# 804/804 [==============================] - 1s 672us/step - loss: 0.5501 - accuracy: 0.7303
# Epoch 49/100
# 804/804 [==============================] - 1s 676us/step - loss: 0.5502 - accuracy: 0.7308
# Epoch 50/100
# 804/804 [==============================] - 1s 672us/step - loss: 0.5500 - accuracy: 0.7306
# Epoch 51/100
# 804/804 [==============================] - 1s 678us/step - loss: 0.5500 - accuracy: 0.7306
# Epoch 52/100
# 804/804 [==============================] - 1s 657us/step - loss: 0.5500 - accuracy: 0.7303
# Epoch 53/100
# 804/804 [==============================] - 1s 660us/step - loss: 0.5500 - accuracy: 0.7304
# Epoch 54/100
# 804/804 [==============================] - 1s 656us/step - loss: 0.5499 - accuracy: 0.7308
# Epoch 55/100
# 804/804 [==============================] - 1s 658us/step - loss: 0.5498 - accuracy: 0.7310
# Epoch 56/100
# 804/804 [==============================] - 1s 667us/step - loss: 0.5498 - accuracy: 0.7304
# Epoch 57/100
# 804/804 [==============================] - 1s 664us/step - loss: 0.5497 - accuracy: 0.7306
# Epoch 58/100
# 804/804 [==============================] - 1s 674us/step - loss: 0.5497 - accuracy: 0.7308
# Epoch 59/100
# 804/804 [==============================] - 1s 669us/step - loss: 0.5496 - accuracy: 0.7301
# Epoch 60/100
# 804/804 [==============================] - 1s 662us/step - loss: 0.5497 - accuracy: 0.7302
# Epoch 61/100
# 804/804 [==============================] - 1s 667us/step - loss: 0.5497 - accuracy: 0.7312
# Epoch 62/100
# 804/804 [==============================] - 1s 664us/step - loss: 0.5495 - accuracy: 0.7297
# Epoch 63/100
# 804/804 [==============================] - 1s 668us/step - loss: 0.5495 - accuracy: 0.7306
# Epoch 64/100
# 804/804 [==============================] - 1s 665us/step - loss: 0.5495 - accuracy: 0.7299
# Epoch 65/100
# 804/804 [==============================] - 1s 657us/step - loss: 0.5495 - accuracy: 0.7309
# Epoch 66/100
# 804/804 [==============================] - 1s 662us/step - loss: 0.5495 - accuracy: 0.7305
# Epoch 67/100
# 804/804 [==============================] - 1s 661us/step - loss: 0.5492 - accuracy: 0.7308
# Epoch 68/100
# 804/804 [==============================] - 1s 663us/step - loss: 0.5493 - accuracy: 0.7312
# Epoch 69/100
# 804/804 [==============================] - 1s 656us/step - loss: 0.5493 - accuracy: 0.7312
# Epoch 70/100
# 804/804 [==============================] - 1s 650us/step - loss: 0.5492 - accuracy: 0.7310
# Epoch 71/100
# 804/804 [==============================] - 1s 662us/step - loss: 0.5493 - accuracy: 0.7307
# Epoch 72/100
# 804/804 [==============================] - 1s 663us/step - loss: 0.5491 - accuracy: 0.7306
# Epoch 73/100
# 804/804 [==============================] - 1s 662us/step - loss: 0.5492 - accuracy: 0.7303
# Epoch 74/100
# 804/804 [==============================] - 1s 667us/step - loss: 0.5492 - accuracy: 0.7310
# Epoch 75/100
# 804/804 [==============================] - 1s 660us/step - loss: 0.5491 - accuracy: 0.7313
# Epoch 76/100
# 804/804 [==============================] - 1s 665us/step - loss: 0.5491 - accuracy: 0.7314
# Epoch 77/100
# 804/804 [==============================] - 1s 654us/step - loss: 0.5491 - accuracy: 0.7303
# Epoch 78/100
# 804/804 [==============================] - 1s 665us/step - loss: 0.5491 - accuracy: 0.7311
# Epoch 79/100
# 804/804 [==============================] - 1s 657us/step - loss: 0.5491 - accuracy: 0.7309
# Epoch 80/100
# 804/804 [==============================] - 1s 654us/step - loss: 0.5489 - accuracy: 0.7314
# Epoch 81/100
# 804/804 [==============================] - 1s 648us/step - loss: 0.5490 - accuracy: 0.7308
# Epoch 82/100
# 804/804 [==============================] - 1s 652us/step - loss: 0.5489 - accuracy: 0.7300
# Epoch 83/100
# 804/804 [==============================] - 1s 643us/step - loss: 0.5488 - accuracy: 0.7309
# Epoch 84/100
# 804/804 [==============================] - 1s 650us/step - loss: 0.5489 - accuracy: 0.7308
# Epoch 85/100
# 804/804 [==============================] - 1s 651us/step - loss: 0.5487 - accuracy: 0.7307
# Epoch 86/100
# 804/804 [==============================] - 1s 654us/step - loss: 0.5487 - accuracy: 0.7310
# Epoch 87/100
# 804/804 [==============================] - 1s 667us/step - loss: 0.5487 - accuracy: 0.7310
# Epoch 88/100
# 804/804 [==============================] - 1s 663us/step - loss: 0.5487 - accuracy: 0.7320
# Epoch 89/100
# 804/804 [==============================] - 1s 658us/step - loss: 0.5488 - accuracy: 0.7309
# Epoch 90/100
# 804/804 [==============================] - 1s 660us/step - loss: 0.5487 - accuracy: 0.7309
# Epoch 91/100
# 804/804 [==============================] - 1s 657us/step - loss: 0.5487 - accuracy: 0.7311
# Epoch 92/100
# 804/804 [==============================] - 1s 653us/step - loss: 0.5487 - accuracy: 0.7304
# Epoch 93/100
# 804/804 [==============================] - 1s 655us/step - loss: 0.5486 - accuracy: 0.7316
# Epoch 94/100
# 804/804 [==============================] - 1s 655us/step - loss: 0.5487 - accuracy: 0.7315
# Epoch 95/100
# 804/804 [==============================] - 1s 655us/step - loss: 0.5486 - accuracy: 0.7306
# Epoch 96/100
# 804/804 [==============================] - 1s 657us/step - loss: 0.5485 - accuracy: 0.7315
# Epoch 97/100
# 804/804 [==============================] - 1s 663us/step - loss: 0.5485 - accuracy: 0.7316
# Epoch 98/100
# 804/804 [==============================] - 1s 653us/step - loss: 0.5485 - accuracy: 0.7314
# Epoch 99/100
# 804/804 [==============================] - 1s 659us/step - loss: 0.5485 - accuracy: 0.7303
# Epoch 100/100
# 804/804 [==============================] - 1s 666us/step - loss: 0.5484 - accuracy: 0.7311

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5553 - accuracy: 0.7265 - 224ms/epoch - 837us/step
# Loss: 0.5552964806556702, Accuracy: 0.7265306115150452

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")

# %% [markdown]
# # Model 2

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

number_input_features = len( X_train_scaled[0])
hidden_nodes_layer1=80
hidden_nodes_layer2=30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# # Third hidden layer
# nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 80)                3600
#
#  dense_7 (Dense)             (None, 30)                2430
#
#  dense_8 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 6,061
# Trainable params: 6,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 713us/step - loss: 0.5706 - accuracy: 0.7193
# Epoch 2/100
# 804/804 [==============================] - 1s 753us/step - loss: 0.5534 - accuracy: 0.7284
# Epoch 3/100
# 804/804 [==============================] - 1s 707us/step - loss: 0.5502 - accuracy: 0.7307
# Epoch 4/100
# 804/804 [==============================] - 1s 734us/step - loss: 0.5493 - accuracy: 0.7314
# Epoch 5/100
# 804/804 [==============================] - 1s 712us/step - loss: 0.5488 - accuracy: 0.7305
# Epoch 6/100
# 804/804 [==============================] - 1s 734us/step - loss: 0.5467 - accuracy: 0.7325
# Epoch 7/100
# 804/804 [==============================] - 1s 746us/step - loss: 0.5459 - accuracy: 0.7329
# Epoch 8/100
# 804/804 [==============================] - 1s 733us/step - loss: 0.5452 - accuracy: 0.7332
# Epoch 9/100
# 804/804 [==============================] - 1s 751us/step - loss: 0.5459 - accuracy: 0.7333
# Epoch 10/100
# 804/804 [==============================] - 1s 720us/step - loss: 0.5448 - accuracy: 0.7325
# Epoch 11/100
# 804/804 [==============================] - 1s 725us/step - loss: 0.5441 - accuracy: 0.7339
# Epoch 12/100
# 804/804 [==============================] - 1s 730us/step - loss: 0.5432 - accuracy: 0.7341
# Epoch 13/100
# 804/804 [==============================] - 1s 714us/step - loss: 0.5434 - accuracy: 0.7339
# Epoch 14/100
# 804/804 [==============================] - 1s 727us/step - loss: 0.5431 - accuracy: 0.7342
# Epoch 15/100
# 804/804 [==============================] - 1s 709us/step - loss: 0.5423 - accuracy: 0.7348
# Epoch 16/100
# 804/804 [==============================] - 1s 741us/step - loss: 0.5421 - accuracy: 0.7341
# Epoch 17/100
# 804/804 [==============================] - 1s 733us/step - loss: 0.5422 - accuracy: 0.7359
# Epoch 18/100
# 804/804 [==============================] - 1s 722us/step - loss: 0.5420 - accuracy: 0.7348
# Epoch 19/100
# 804/804 [==============================] - 1s 738us/step - loss: 0.5417 - accuracy: 0.7341
# Epoch 20/100
# 804/804 [==============================] - 1s 712us/step - loss: 0.5412 - accuracy: 0.7355
# Epoch 21/100
# 804/804 [==============================] - 1s 745us/step - loss: 0.5411 - accuracy: 0.7362
# Epoch 22/100
# 804/804 [==============================] - 1s 738us/step - loss: 0.5409 - accuracy: 0.7355
# Epoch 23/100
# 804/804 [==============================] - 1s 720us/step - loss: 0.5403 - accuracy: 0.7357
# Epoch 24/100
# 804/804 [==============================] - 1s 745us/step - loss: 0.5407 - accuracy: 0.7364
# Epoch 25/100
# 804/804 [==============================] - 1s 738us/step - loss: 0.5402 - accuracy: 0.7367
# Epoch 26/100
# 804/804 [==============================] - 1s 743us/step - loss: 0.5400 - accuracy: 0.7378
# Epoch 27/100
# 804/804 [==============================] - 1s 715us/step - loss: 0.5397 - accuracy: 0.7375
# Epoch 28/100
# 804/804 [==============================] - 1s 728us/step - loss: 0.5398 - accuracy: 0.7360
# Epoch 29/100
# 804/804 [==============================] - 1s 730us/step - loss: 0.5392 - accuracy: 0.7367
# Epoch 30/100
# 804/804 [==============================] - 1s 768us/step - loss: 0.5394 - accuracy: 0.7369
# Epoch 31/100
# 804/804 [==============================] - 1s 850us/step - loss: 0.5393 - accuracy: 0.7368
# Epoch 32/100
# 804/804 [==============================] - 1s 856us/step - loss: 0.5389 - accuracy: 0.7362
# Epoch 33/100
# 804/804 [==============================] - 1s 807us/step - loss: 0.5383 - accuracy: 0.7378
# Epoch 34/100
# 804/804 [==============================] - 1s 846us/step - loss: 0.5389 - accuracy: 0.7380
# Epoch 35/100
# 804/804 [==============================] - 1s 838us/step - loss: 0.5381 - accuracy: 0.7389
# Epoch 36/100
# 804/804 [==============================] - 1s 822us/step - loss: 0.5381 - accuracy: 0.7375
# Epoch 37/100
# 804/804 [==============================] - 1s 851us/step - loss: 0.5381 - accuracy: 0.7370
# Epoch 38/100
# 804/804 [==============================] - 1s 805us/step - loss: 0.5376 - accuracy: 0.7381
# Epoch 39/100
# 804/804 [==============================] - 1s 792us/step - loss: 0.5380 - accuracy: 0.7387
# Epoch 40/100
# 804/804 [==============================] - 1s 828us/step - loss: 0.5378 - accuracy: 0.7379
# Epoch 41/100
# 804/804 [==============================] - 1s 851us/step - loss: 0.5378 - accuracy: 0.7385
# Epoch 42/100
# 804/804 [==============================] - 1s 809us/step - loss: 0.5374 - accuracy: 0.7377
# Epoch 43/100
# 804/804 [==============================] - 1s 840us/step - loss: 0.5374 - accuracy: 0.7381
# Epoch 44/100
# 804/804 [==============================] - 1s 821us/step - loss: 0.5371 - accuracy: 0.7378
# Epoch 45/100
# 804/804 [==============================] - 1s 807us/step - loss: 0.5371 - accuracy: 0.7379
# Epoch 46/100
# 804/804 [==============================] - 1s 815us/step - loss: 0.5370 - accuracy: 0.7383
# Epoch 47/100
# 804/804 [==============================] - 1s 775us/step - loss: 0.5374 - accuracy: 0.7381
# Epoch 48/100
# 804/804 [==============================] - 1s 796us/step - loss: 0.5368 - accuracy: 0.7386
# Epoch 49/100
# 804/804 [==============================] - 1s 874us/step - loss: 0.5368 - accuracy: 0.7372
# Epoch 50/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5367 - accuracy: 0.7384
# Epoch 51/100
# 804/804 [==============================] - 1s 799us/step - loss: 0.5367 - accuracy: 0.7379
# Epoch 52/100
# 804/804 [==============================] - 1s 846us/step - loss: 0.5366 - accuracy: 0.7383
# Epoch 53/100
# 804/804 [==============================] - 1s 817us/step - loss: 0.5363 - accuracy: 0.7381
# Epoch 54/100
# 804/804 [==============================] - 1s 820us/step - loss: 0.5363 - accuracy: 0.7385
# Epoch 55/100
# 804/804 [==============================] - 1s 861us/step - loss: 0.5358 - accuracy: 0.7385
# Epoch 56/100
# 804/804 [==============================] - 1s 902us/step - loss: 0.5360 - accuracy: 0.7386
# Epoch 57/100
# 804/804 [==============================] - 1s 811us/step - loss: 0.5362 - accuracy: 0.7378
# Epoch 58/100
# 804/804 [==============================] - 1s 851us/step - loss: 0.5364 - accuracy: 0.7381
# Epoch 59/100
# 804/804 [==============================] - 1s 855us/step - loss: 0.5359 - accuracy: 0.7379
# Epoch 60/100
# 804/804 [==============================] - 1s 831us/step - loss: 0.5358 - accuracy: 0.7392
# Epoch 61/100
# 804/804 [==============================] - 1s 899us/step - loss: 0.5357 - accuracy: 0.7383
# Epoch 62/100
# 804/804 [==============================] - 1s 922us/step - loss: 0.5358 - accuracy: 0.7395
# Epoch 63/100
# 804/804 [==============================] - 1s 878us/step - loss: 0.5355 - accuracy: 0.7390
# Epoch 64/100
# 804/804 [==============================] - 1s 919us/step - loss: 0.5354 - accuracy: 0.7392
# Epoch 65/100
# 804/804 [==============================] - 1s 847us/step - loss: 0.5355 - accuracy: 0.7376
# Epoch 66/100
# 804/804 [==============================] - 1s 811us/step - loss: 0.5352 - accuracy: 0.7391
# Epoch 67/100
# 804/804 [==============================] - 1s 780us/step - loss: 0.5358 - accuracy: 0.7394
# Epoch 68/100
# 804/804 [==============================] - 1s 810us/step - loss: 0.5352 - accuracy: 0.7388
# Epoch 69/100
# 804/804 [==============================] - 1s 765us/step - loss: 0.5352 - accuracy: 0.7389
# Epoch 70/100
# 804/804 [==============================] - 1s 812us/step - loss: 0.5348 - accuracy: 0.7403
# Epoch 71/100
# 804/804 [==============================] - 1s 812us/step - loss: 0.5348 - accuracy: 0.7391
# Epoch 72/100
# 804/804 [==============================] - 1s 787us/step - loss: 0.5348 - accuracy: 0.7393
# Epoch 73/100
# 804/804 [==============================] - 1s 818us/step - loss: 0.5348 - accuracy: 0.7386
# Epoch 74/100
# 804/804 [==============================] - 1s 810us/step - loss: 0.5347 - accuracy: 0.7389
# Epoch 75/100
# 804/804 [==============================] - 1s 787us/step - loss: 0.5342 - accuracy: 0.7399
# Epoch 76/100
# 804/804 [==============================] - 1s 826us/step - loss: 0.5343 - accuracy: 0.7403
# Epoch 77/100
# 804/804 [==============================] - 1s 825us/step - loss: 0.5346 - accuracy: 0.7392
# Epoch 78/100
# 804/804 [==============================] - 1s 791us/step - loss: 0.5346 - accuracy: 0.7403
# Epoch 79/100
# 804/804 [==============================] - 1s 825us/step - loss: 0.5345 - accuracy: 0.7403
# Epoch 80/100
# 804/804 [==============================] - 1s 796us/step - loss: 0.5343 - accuracy: 0.7397
# Epoch 81/100
# 804/804 [==============================] - 1s 791us/step - loss: 0.5347 - accuracy: 0.7395
# Epoch 82/100
# 804/804 [==============================] - 1s 823us/step - loss: 0.5345 - accuracy: 0.7399
# Epoch 83/100
# 804/804 [==============================] - 1s 792us/step - loss: 0.5340 - accuracy: 0.7391
# Epoch 84/100
# 804/804 [==============================] - 1s 798us/step - loss: 0.5344 - accuracy: 0.7395
# Epoch 85/100
# 804/804 [==============================] - 1s 826us/step - loss: 0.5341 - accuracy: 0.7392
# Epoch 86/100
# 804/804 [==============================] - 1s 857us/step - loss: 0.5338 - accuracy: 0.7404
# Epoch 87/100
# 804/804 [==============================] - 1s 816us/step - loss: 0.5341 - accuracy: 0.7398
# Epoch 88/100
# 804/804 [==============================] - 1s 816us/step - loss: 0.5337 - accuracy: 0.7401
# Epoch 89/100
# 804/804 [==============================] - 1s 786us/step - loss: 0.5342 - accuracy: 0.7393
# Epoch 90/100
# 804/804 [==============================] - 1s 835us/step - loss: 0.5335 - accuracy: 0.7406
# Epoch 91/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5340 - accuracy: 0.7399
# Epoch 92/100
# 804/804 [==============================] - 1s 809us/step - loss: 0.5334 - accuracy: 0.7402
# Epoch 93/100
# 804/804 [==============================] - 1s 827us/step - loss: 0.5336 - accuracy: 0.7395
# Epoch 94/100
# 804/804 [==============================] - 1s 816us/step - loss: 0.5340 - accuracy: 0.7400
# Epoch 95/100
# 804/804 [==============================] - 1s 826us/step - loss: 0.5337 - accuracy: 0.7392
# Epoch 96/100
# 804/804 [==============================] - 1s 847us/step - loss: 0.5333 - accuracy: 0.7393
# Epoch 97/100
# 804/804 [==============================] - 1s 806us/step - loss: 0.5342 - accuracy: 0.7400
# Epoch 98/100
# 804/804 [==============================] - 1s 795us/step - loss: 0.5343 - accuracy: 0.7387
# Epoch 99/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5332 - accuracy: 0.7414
# Epoch 100/100
# 804/804 [==============================] - 1s 812us/step - loss: 0.5335 - accuracy: 0.7398

# %% [markdown]
# # Model 3

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = application_df['CLASSIFICATION'].value_counts().loc[lambda x : x<100].index.tolist()
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dum_df = pd.get_dummies(application_df)
application_dum_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 50 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_dum_df.drop(['IS_SUCCESSFUL'], axis=1)
y = application_dum_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
number_input_features = len( X_train_scaled[0])
hidden_nodes_layer1=80
hidden_nodes_layer2=30
hidden_nodes_layer3 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# # Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 80)                4000
#
#  dense_10 (Dense)            (None, 30)                2430
#
#  dense_11 (Dense)            (None, 10)                310
#
#  dense_12 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 6,751
# Trainable params: 6,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 759us/step - loss: 0.5702 - accuracy: 0.7172
# Epoch 2/100
# 804/804 [==============================] - 1s 750us/step - loss: 0.5524 - accuracy: 0.7282
# Epoch 3/100
# 804/804 [==============================] - 1s 745us/step - loss: 0.5490 - accuracy: 0.7297
# Epoch 4/100
# 804/804 [==============================] - 1s 751us/step - loss: 0.5479 - accuracy: 0.7310
# Epoch 5/100
# 804/804 [==============================] - 1s 750us/step - loss: 0.5469 - accuracy: 0.7294
# Epoch 6/100
# 804/804 [==============================] - 1s 756us/step - loss: 0.5462 - accuracy: 0.7297
# Epoch 7/100
# 804/804 [==============================] - 1s 755us/step - loss: 0.5448 - accuracy: 0.7315
# Epoch 8/100
# 804/804 [==============================] - 1s 759us/step - loss: 0.5436 - accuracy: 0.7330
# Epoch 9/100
# 804/804 [==============================] - 1s 754us/step - loss: 0.5430 - accuracy: 0.7336
# Epoch 10/100
# 804/804 [==============================] - 1s 758us/step - loss: 0.5423 - accuracy: 0.7333
# Epoch 11/100
# 804/804 [==============================] - 1s 763us/step - loss: 0.5424 - accuracy: 0.7346
# Epoch 12/100
# 804/804 [==============================] - 1s 755us/step - loss: 0.5419 - accuracy: 0.7333
# Epoch 13/100
# 804/804 [==============================] - 1s 750us/step - loss: 0.5417 - accuracy: 0.7353
# Epoch 14/100
# 804/804 [==============================] - 1s 753us/step - loss: 0.5415 - accuracy: 0.7341
# Epoch 15/100
# 804/804 [==============================] - 1s 750us/step - loss: 0.5403 - accuracy: 0.7352
# Epoch 16/100
# 804/804 [==============================] - 1s 751us/step - loss: 0.5404 - accuracy: 0.7363
# Epoch 17/100
# 804/804 [==============================] - 1s 758us/step - loss: 0.5399 - accuracy: 0.7357
# Epoch 18/100
# 804/804 [==============================] - 1s 763us/step - loss: 0.5401 - accuracy: 0.7357
# Epoch 19/100
# 804/804 [==============================] - 1s 755us/step - loss: 0.5395 - accuracy: 0.7358
# Epoch 20/100
# 804/804 [==============================] - 1s 756us/step - loss: 0.5394 - accuracy: 0.7348
# Epoch 21/100
# 804/804 [==============================] - 1s 766us/step - loss: 0.5388 - accuracy: 0.7365
# Epoch 22/100
# 804/804 [==============================] - 1s 761us/step - loss: 0.5386 - accuracy: 0.7362
# Epoch 23/100
# 804/804 [==============================] - 1s 765us/step - loss: 0.5381 - accuracy: 0.7368
# Epoch 24/100
# 804/804 [==============================] - 1s 768us/step - loss: 0.5385 - accuracy: 0.7356
# Epoch 25/100
# 804/804 [==============================] - 1s 755us/step - loss: 0.5379 - accuracy: 0.7367
# Epoch 26/100
# 804/804 [==============================] - 1s 761us/step - loss: 0.5381 - accuracy: 0.7365
# Epoch 27/100
# 804/804 [==============================] - 1s 763us/step - loss: 0.5378 - accuracy: 0.7369
# Epoch 28/100
# 804/804 [==============================] - 1s 759us/step - loss: 0.5373 - accuracy: 0.7374
# Epoch 29/100
# 804/804 [==============================] - 1s 759us/step - loss: 0.5375 - accuracy: 0.7372
# Epoch 30/100
# 804/804 [==============================] - 1s 754us/step - loss: 0.5369 - accuracy: 0.7381
# Epoch 31/100
# 804/804 [==============================] - 1s 774us/step - loss: 0.5369 - accuracy: 0.7372
# Epoch 32/100
# 804/804 [==============================] - 1s 756us/step - loss: 0.5366 - accuracy: 0.7371
# Epoch 33/100
# 804/804 [==============================] - 1s 766us/step - loss: 0.5364 - accuracy: 0.7371
# Epoch 34/100
# 804/804 [==============================] - 1s 758us/step - loss: 0.5367 - accuracy: 0.7368
# Epoch 35/100
# 804/804 [==============================] - 1s 753us/step - loss: 0.5362 - accuracy: 0.7370
# Epoch 36/100
# 804/804 [==============================] - 1s 756us/step - loss: 0.5360 - accuracy: 0.7383
# Epoch 37/100
# 804/804 [==============================] - 1s 763us/step - loss: 0.5361 - accuracy: 0.7385
# Epoch 38/100
# 804/804 [==============================] - 1s 763us/step - loss: 0.5358 - accuracy: 0.7379
# Epoch 39/100
# 804/804 [==============================] - 1s 758us/step - loss: 0.5357 - accuracy: 0.7372
# Epoch 40/100
# 804/804 [==============================] - 1s 759us/step - loss: 0.5357 - accuracy: 0.7378
# Epoch 41/100
# 804/804 [==============================] - 1s 775us/step - loss: 0.5357 - accuracy: 0.7378
# Epoch 42/100
# 804/804 [==============================] - 1s 758us/step - loss: 0.5352 - accuracy: 0.7385
# Epoch 43/100
# 804/804 [==============================] - 1s 763us/step - loss: 0.5347 - accuracy: 0.7382
# Epoch 44/100
# 804/804 [==============================] - 1s 773us/step - loss: 0.5353 - accuracy: 0.7379
# Epoch 45/100
# 804/804 [==============================] - 1s 765us/step - loss: 0.5348 - accuracy: 0.7383
# Epoch 46/100
# 804/804 [==============================] - 1s 765us/step - loss: 0.5351 - accuracy: 0.7387
# Epoch 47/100
# 804/804 [==============================] - 1s 768us/step - loss: 0.5352 - accuracy: 0.7377
# Epoch 48/100
# 804/804 [==============================] - 1s 770us/step - loss: 0.5345 - accuracy: 0.7385
# Epoch 49/100
# 804/804 [==============================] - 1s 761us/step - loss: 0.5346 - accuracy: 0.7387
# Epoch 50/100
# 804/804 [==============================] - 1s 779us/step - loss: 0.5343 - accuracy: 0.7387
# Epoch 51/100
# 804/804 [==============================] - 1s 759us/step - loss: 0.5340 - accuracy: 0.7373
# Epoch 52/100
# 804/804 [==============================] - 1s 759us/step - loss: 0.5344 - accuracy: 0.7390
# Epoch 53/100
# 804/804 [==============================] - 1s 787us/step - loss: 0.5340 - accuracy: 0.7387
# Epoch 54/100
# 804/804 [==============================] - 1s 830us/step - loss: 0.5339 - accuracy: 0.7391
# Epoch 55/100
# 804/804 [==============================] - 1s 830us/step - loss: 0.5336 - accuracy: 0.7390
# Epoch 56/100
# 804/804 [==============================] - 1s 841us/step - loss: 0.5340 - accuracy: 0.7383
# Epoch 57/100
# 804/804 [==============================] - 1s 840us/step - loss: 0.5338 - accuracy: 0.7396
# Epoch 58/100
# 804/804 [==============================] - 1s 830us/step - loss: 0.5335 - accuracy: 0.7389
# Epoch 59/100
# 804/804 [==============================] - 1s 827us/step - loss: 0.5334 - accuracy: 0.7392
# Epoch 60/100
# 804/804 [==============================] - 1s 845us/step - loss: 0.5335 - accuracy: 0.7395
# Epoch 61/100
# 804/804 [==============================] - 1s 827us/step - loss: 0.5332 - accuracy: 0.7392
# Epoch 62/100
# 804/804 [==============================] - 1s 889us/step - loss: 0.5332 - accuracy: 0.7390
# Epoch 63/100
# 804/804 [==============================] - 1s 827us/step - loss: 0.5333 - accuracy: 0.7388
# Epoch 64/100
# 804/804 [==============================] - 1s 830us/step - loss: 0.5332 - accuracy: 0.7385
# Epoch 65/100
# 804/804 [==============================] - 1s 842us/step - loss: 0.5334 - accuracy: 0.7389
# Epoch 66/100
# 804/804 [==============================] - 1s 830us/step - loss: 0.5326 - accuracy: 0.7394
# Epoch 67/100
# 804/804 [==============================] - 1s 825us/step - loss: 0.5330 - accuracy: 0.7391
# Epoch 68/100
# 804/804 [==============================] - 1s 847us/step - loss: 0.5330 - accuracy: 0.7393
# Epoch 69/100
# 804/804 [==============================] - 1s 836us/step - loss: 0.5326 - accuracy: 0.7389
# Epoch 70/100
# 804/804 [==============================] - 1s 826us/step - loss: 0.5329 - accuracy: 0.7393
# Epoch 71/100
# 804/804 [==============================] - 1s 825us/step - loss: 0.5333 - accuracy: 0.7399
# Epoch 72/100
# 804/804 [==============================] - 1s 823us/step - loss: 0.5326 - accuracy: 0.7388
# Epoch 73/100
# 804/804 [==============================] - 1s 830us/step - loss: 0.5322 - accuracy: 0.7395
# Epoch 74/100
# 804/804 [==============================] - 1s 826us/step - loss: 0.5324 - accuracy: 0.7402
# Epoch 75/100
# 804/804 [==============================] - 1s 832us/step - loss: 0.5326 - accuracy: 0.7400
# Epoch 76/100
# 804/804 [==============================] - 1s 830us/step - loss: 0.5321 - accuracy: 0.7394
# Epoch 77/100
# 804/804 [==============================] - 1s 835us/step - loss: 0.5320 - accuracy: 0.7399
# Epoch 78/100
# 804/804 [==============================] - 1s 854us/step - loss: 0.5325 - accuracy: 0.7386
# Epoch 79/100
# 804/804 [==============================] - 1s 837us/step - loss: 0.5321 - accuracy: 0.7395
# Epoch 80/100
# 804/804 [==============================] - 1s 837us/step - loss: 0.5320 - accuracy: 0.7397
# Epoch 81/100
# 804/804 [==============================] - 1s 826us/step - loss: 0.5320 - accuracy: 0.7393
# Epoch 82/100
# 804/804 [==============================] - 1s 828us/step - loss: 0.5320 - accuracy: 0.7392
# Epoch 83/100
# 804/804 [==============================] - 1s 830us/step - loss: 0.5322 - accuracy: 0.7403
# Epoch 84/100
# 804/804 [==============================] - 1s 835us/step - loss: 0.5315 - accuracy: 0.7395
# Epoch 85/100
# 804/804 [==============================] - 1s 835us/step - loss: 0.5316 - accuracy: 0.7399
# Epoch 86/100
# 804/804 [==============================] - 1s 847us/step - loss: 0.5321 - accuracy: 0.7395
# Epoch 87/100
# 804/804 [==============================] - 1s 832us/step - loss: 0.5322 - accuracy: 0.7401
# Epoch 88/100
# 804/804 [==============================] - 1s 820us/step - loss: 0.5313 - accuracy: 0.7403
# Epoch 89/100
# 804/804 [==============================] - 1s 818us/step - loss: 0.5319 - accuracy: 0.7395
# Epoch 90/100
# 804/804 [==============================] - 1s 823us/step - loss: 0.5314 - accuracy: 0.7399
# Epoch 91/100
# 804/804 [==============================] - 1s 823us/step - loss: 0.5315 - accuracy: 0.7399
# Epoch 92/100
# 804/804 [==============================] - 1s 837us/step - loss: 0.5317 - accuracy: 0.7400
# Epoch 93/100
# 804/804 [==============================] - 1s 821us/step - loss: 0.5314 - accuracy: 0.7402
# Epoch 94/100
# 804/804 [==============================] - 1s 821us/step - loss: 0.5312 - accuracy: 0.7399
# Epoch 95/100
# 804/804 [==============================] - 1s 847us/step - loss: 0.5319 - accuracy: 0.7393
# Epoch 96/100
# 804/804 [==============================] - 1s 838us/step - loss: 0.5310 - accuracy: 0.7401
# Epoch 97/100
# 804/804 [==============================] - 1s 876us/step - loss: 0.5309 - accuracy: 0.7399
# Epoch 98/100
# 804/804 [==============================] - 1s 873us/step - loss: 0.5312 - accuracy: 0.7404
# Epoch 99/100
# 804/804 [==============================] - 1s 825us/step - loss: 0.5311 - accuracy: 0.7402
# Epoch 100/100
# 804/804 [==============================] - 1s 832us/step - loss: 0.5308 - accuracy: 0.7404

# %%
nn.save("AlphabetSoupCharity3.h5")
